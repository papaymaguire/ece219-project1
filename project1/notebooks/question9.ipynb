# %%
import pandas as pd
import numpy as np
np.random.seed(42)
import random
random.seed(42)
from project1 import defs

dim_reduced_train_features: pd.DataFrame = defs.load_asset_value("dim_reduced_train_features")
train: pd.DataFrame = defs.load_asset_value("train")
dim_reduced_test_features: pd.DataFrame = defs.load_asset_value("dim_reduced_test_features")
test: pd.DataFrame = defs.load_asset_value("test")
# Out:
# 2024-04-13 11:43:55 -0700 - dagster - DEBUG - system - Loading file from: /home/maguire/ucla/ece219/project1/project1/../data/dim_reduced_train_features using PickledObjectFilesystemIOManager...
# 2024-04-13 11:43:55 -0700 - dagster - DEBUG - system - Loading file from: /home/maguire/ucla/ece219/project1/project1/../data/train using PickledObjectFilesystemIOManager...
# 2024-04-13 11:43:55 -0700 - dagster - DEBUG - system - Loading file from: /home/maguire/ucla/ece219/project1/project1/../data/dim_reduced_test_features using PickledObjectFilesystemIOManager...
# 2024-04-13 11:43:55 -0700 - dagster - DEBUG - system - Loading file from: /home/maguire/ucla/ece219/project1/project1/../data/test using PickledObjectFilesystemIOManager...

# %%
map_row_to_class = {
    0:"basketball",
    1:"baseball",
    2:"tennis",
    3:"football",
    4:"soccer",
    5:"forest fire",
    6:"flood",
    7:"earthquake",
    8:"drought",
    9:"heatwave"
}

# %%
from sklearn.multiclass import OneVsOneClassifier, OneVsRestClassifier
from sklearn.naive_bayes import GaussianNB

nb_1v1_clf = OneVsOneClassifier(GaussianNB())

# %%
nb_1v1_clf.fit(dim_reduced_train_features, train['leaf_label'])
# Out:
# OneVsOneClassifier(estimator=GaussianNB())

# %%
from project1.utils.MetricsAnalyzer import MetricsAnalyzer

# %%
nb_1v1_metrics = MetricsAnalyzer(nb_1v1_clf, dim_reduced_test_features, test['leaf_label'])
nb_1v1_metrics.print_all(roc=False)
# Out:
# Confusion Matrix:
# [[54  0  1  0  2  3  0  3  1 11]
#  [ 2 76  0  0  0  5  0  0  1  6]
#  [ 0  0 60  0  0  0  1  3  1  3]
#  [ 0  0  1 43  0  0  0  0  0 10]
#  [ 1  0  1  0 61  0  1  1  0  1]
#  [ 0  1  0  0  0 50  0  0  8  2]
#  [ 2  0  9  1  2  0 16 31  3  9]
#  [ 1  0  5  0  4  1 25 19  1 11]
#  [ 0  1  0  0  0  1  0  0 66  5]
#  [ 6  0  0  0  2  0  0  1  3 57]]
# Accuracy Score:
# 0.7212643678160919
# Recall Score:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 nb_1v1_metrics = MetricsAnalyzer(nb_1v1_clf, dim_reduced_test_features, test['leaf_label'])
# ----> 2 nb_1v1_metrics.print_all(roc=False)
#
# File ~/ucla/ece219/project1/project1/utils/MetricsAnalyzer.py:20, in MetricsAnalyzer.print_all(self, roc, plot_title)
#      18 self.print_accuracy()
#      19 print("Recall Score: ")
# ---> 20 self.print_recall()
# ...
